# %% [markdown]
# # 1.Perkenalan
#  Nama : Sandika Akbar
#  Batch : 8
#
#     Tujuan pengolahan data ini adalah mencari pokemon mana yang terkuat dan juga terlemah yang dibagi kedalam 2 jenis legendary dan non legendary, disini paramater yang digunakan untuk mengambil kesimpulan terkuat dan terlemah adalah 'Total', dan juga Type pokemon mana yang memiliki rata rata pokemon kuat

# %% [markdown]
# # 2. Import Pustaka

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 3. Data Loading

# %%
pd.read_csv('dataset/Pokemon.csv')
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pk=pd.read_csv('dataset/Pokemon.csv')
pd.set_option('display.max_columns',None)
pk
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# terdapat 800 data entry dari 721 pokemon, hal ini dikarenakan terdapat id yang diulangi saat terjadi perubahan khusus pokemon

# %%
pk.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
pk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
pk.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# terdapat 386 data kosong di kolom type2

# %%
pk.head(3)
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %% [markdown]
# # 4. Data Cleaning

# %%
pk.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pk_2= pk.copy()

# %%
pk_2.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pk_2['Name'] = pk_2['Name'].str.replace(".*(?=Mega)", "")
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9580\3062967081.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   pk_2['Name'] = pk_2['Name'].str.replace(".*(?=Mega)", "")

# %%
pk_2.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Pengubahan dikolom 'Name' agar tidak terjadi pengulangan nama seperti "BeedrillMega Beedrill" dengan perintah ganti kata didepan 'Mega' menjadi'' dengan perintah pk_2['Name'] = pk_2['Name'].str.replace(".*(?=Mega)", "")

# %%
pk_2['Type 2'].fillna(pk_2['Type 1'], inplace=True)

# %% [markdown]
# Perintah untuk mengisi kolom 'Type 2' dengan 'Type 1' apa bila bernilai NaN

# %%
pk_2.head()
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire    Fire    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pk_3=pk_2.set_index('Name')

# %%
pk_4=pk_3.drop('Generation',axis=1)
pk_4.head()
# Out:
#                # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur      1  Grass  Poison    318  45      49       49       65       65
# Ivysaur        2  Grass  Poison    405  60      62       63       80       80
# Venusaur       3  Grass  Poison    525  80      82       83      100      100
# Mega Venusaur  3  Grass  Poison    625  80     100      123      122      120
# Charmander     4   Fire    Fire    309  39      52       43       60       50
#
#                Speed  Legendary
# Name
# Bulbasaur         45      False
# Ivysaur           60      False
# Venusaur          80      False
# Mega Venusaur     80      False
# Charmander        65      False

# %% [markdown]
# Mengubah index menjadi kolom 'Name' dan 'Type 1' menjadi 'Type' agar lebih menarik untuk dilihat dan menghapus kolom 'Generation'

# %% [markdown]
# # 5. Data Exploration

# %%
pk_4.head()
# Out:
#                # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur      1  Grass  Poison    318  45      49       49       65       65
# Ivysaur        2  Grass  Poison    405  60      62       63       80       80
# Venusaur       3  Grass  Poison    525  80      82       83      100      100
# Mega Venusaur  3  Grass  Poison    625  80     100      123      122      120
# Charmander     4   Fire    Fire    309  39      52       43       60       50
#
#                Speed  Legendary
# Name
# Bulbasaur         45      False
# Ivysaur           60      False
# Venusaur          80      False
# Mega Venusaur     80      False
# Charmander        65      False

# %%
legend = pk_4[pk_4['Legendary'] == True]
legend
# Out:
#                        #    Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# Articuno             144       Ice    Flying    580   90      85      100
# Zapdos               145  Electric    Flying    580   90      90       85
# Moltres              146      Fire    Flying    580   90     100       90
# Mewtwo               150   Psychic   Psychic    680  106     110       90
# Mega Mewtwo X        150   Psychic  Fighting    780  106     190      100
# ...                  ...       ...       ...    ...  ...     ...      ...
# Diancie              719      Rock     Fairy    600   50     100      150
# Mega Diancie         719      Rock     Fairy    700   50     160      110
# HoopaHoopa Confined  720   Psychic     Ghost    600   80     110       60
# HoopaHoopa Unbound   720   Psychic      Dark    680   80     160       60
# Volcanion            721      Fire     Water    600   80     110      120
#
#                      Sp. Atk  Sp. Def  Speed  Legendary
# Name
# ...

# %%
non_legend = pk_4[pk_4['Legendary'] == False]
non_legend
# Out:
#                        #  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1   Grass  Poison    318  45      49       49       65
# Ivysaur                2   Grass  Poison    405  60      62       63       80
# Venusaur               3   Grass  Poison    525  80      82       83      100
# Mega Venusaur          3   Grass  Poison    625  80     100      123      122
# Charmander             4    Fire    Fire    309  39      52       43       60
# ...                  ...     ...     ...    ...  ..     ...      ...      ...
# GourgeistSuper Size  711   Ghost   Grass    494  85     100      122       58
# Bergmite             712     Ice     Ice    304  55      69       85       32
# Avalugg              713     Ice     Ice    514  95     117      184       44
# Noibat               714  Flying  Dragon    245  40      30       35       45
# Noivern              715  Flying  Dragon    535  85      70       80       97
#
# ...

# %%
legend.sort_values('Total', ascending=False).head()
# Out:
#                          #   Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# Mega Mewtwo X          150  Psychic  Fighting    780  106     190      100
# Mega Mewtwo Y          150  Psychic   Psychic    780  106     150       70
# Mega Rayquaza          384   Dragon    Flying    780  105     180      100
# KyogrePrimal Kyogre    382    Water     Water    770  100     150       90
# GroudonPrimal Groudon  383   Ground      Fire    770  100     180      160
#
#                        Sp. Atk  Sp. Def  Speed  Legendary
# Name
# Mega Mewtwo X              154      100    130       True
# Mega Mewtwo Y              194      120    140       True
# Mega Rayquaza              180      100    115       True
# KyogrePrimal Kyogre        180      160     90       True
# GroudonPrimal Groudon      150       90     90       True

# %% [markdown]
# Dapat diambil kesimpulan Pokemon Legendary memiliki status tertinggi bernilai 780

# %%
legend.sort_values('Total', ascending=True).head(10)
# Out:
#                             #    Type 1    Type 2  Total  HP  Attack  Defense  \
# Name
# Articuno                  144       Ice    Flying    580  90      85      100
# Azelf                     482   Psychic   Psychic    580  75     125       70
# Cobalion                  638     Steel  Fighting    580  91      90      129
# Terrakion                 639      Rock  Fighting    580  91     129       90
# Virizion                  640     Grass  Fighting    580  91      90       72
# TornadusIncarnate Forme   641    Flying    Flying    580  79     115       70
# TornadusTherian Forme     641    Flying    Flying    580  79     100       80
# ThundurusIncarnate Forme  642  Electric    Flying    580  79     115       70
# Mesprit                   481   Psychic   Psychic    580  80     105      105
# Registeel                 379     Steel     Steel    580  80      75      150
#
#                           Sp. Atk  Sp. Def  Speed  Legendary
# Name
# ...

# %% [markdown]
# Dapat diambil kesimpulan Pokemon Legendary memiliki status terendah bernilai 580

# %%
non_legend.sort_values('Total', ascending=False).head()
# Out:
#                   #  Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Mega Metagross  376   Steel  Psychic    700   80     145      150      105
# Mega Garchomp   445  Dragon   Ground    700  108     170      115      120
# Mega Salamence  373  Dragon   Flying    700   95     145      130      120
# Mega Tyranitar  248    Rock     Dark    700  100     164      150       95
# Slaking         289  Normal   Normal    670  150     160      100       95
#
#                 Sp. Def  Speed  Legendary
# Name
# Mega Metagross      110    110      False
# Mega Garchomp        95     92      False
# Mega Salamence       90    120      False
# Mega Tyranitar      120     71      False
# Slaking              65    100      False

# %% [markdown]
# Dapat diambil kesimpulan Pokemon non-Legendary memiliki status tertinggi bernilai 700

# %%
non_legend.sort_values('Total', ascending=True).head()
# Out:
#              #  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Sunkern    191   Grass   Grass    180  30      30       30       30       30
# Azurill    298  Normal   Fairy    190  50      20       40       20       40
# Kricketot  401     Bug     Bug    194  37      25       41       25       41
# Weedle      13     Bug  Poison    195  40      35       30       20       20
# Caterpie    10     Bug     Bug    195  45      30       35       20       20
#
#            Speed  Legendary
# Name
# Sunkern       30      False
# Azurill       20      False
# Kricketot     25      False
# Weedle        50      False
# Caterpie      45      False

# %% [markdown]
# Dapat diambil kesimpulan Pokemon non-Legendary memiliki status terendah bernilai 180

# %%
legend.groupby(['Type 1',])['Total',].mean()
# Out:
#                Total
# Type 1
# Dark      640.000000
# Dragon    673.333333
# Electric  580.000000
# Fairy     680.000000
# Fire      608.000000
# Flying    580.000000
# Ghost     680.000000
# Grass     593.333333
# Ground    660.000000
# Ice       580.000000
# Normal    695.000000
# Psychic   638.571429
# Rock      615.000000
# Steel     610.000000
# Water     675.000000

# %%
non_legend.groupby(['Type 1'])['Total',].mean()
# Out:
#                Total
# Type 1
# Bug       378.927536
# Dark      432.344828
# Dragon    476.850000
# Electric  429.750000
# Fairy     396.500000
# Fighting  416.444444
# Fire      442.127660
# Flying    390.000000
# Ghost     423.533333
# Grass     413.432836
# Ground    405.714286
# Ice       420.136364
# Normal    395.572917
# Poison    399.142857
# Psychic   423.000000
# Rock      437.625000
# Steel     466.434783
# Water     421.398148

# %%
legend.groupby('Type 1')['Total'].mean().nlargest(3)
# Out:
# Type 1
# Normal    695.0
# Fairy     680.0
# Ghost     680.0
# Name: Total, dtype: float64

# %% [markdown]
# 3 Tipe pokemon legendary dengan nilai 'Total' rata rata tertinggi

# %%
legend.groupby('Type 1')['Total'].mean().nsmallest(3)
# Out:
# Type 1
# Electric    580.0
# Flying      580.0
# Ice         580.0
# Name: Total, dtype: float64

# %% [markdown]
# 3 Tipe pokemon legendary dengan nilai 'Total' rata rata terendah

# %% [markdown]
# Tipe normal merupakan tipe terkuat di jenis pokemon legendary dengan nilai 'Total' 695 dan nilai 'Total' terendah pokemon legendary adalah 580

# %%
non_legend.groupby('Type 1')['Total'].mean().nlargest(3)
# Out:
# Type 1
# Dragon    476.850000
# Steel     466.434783
# Fire      442.127660
# Name: Total, dtype: float64

# %% [markdown]
# 3 Tipe pokemon non-legendary dengan nilai 'Total' rata rata tertinggi

# %%
non_legend.groupby('Type 1')['Total'].mean().nsmallest(3)
# Out:
# Type 1
# Bug       378.927536
# Flying    390.000000
# Normal    395.572917
# Name: Total, dtype: float64

# %% [markdown]
# 3 Tipe pokemon non-legendary dengan nilai 'Total' rata rata terendah

# %% [markdown]
# Tipe Dragon merupakan tipe terkuat di jenis pokemon non_legendary dengan nilai 'Total' 476,85 dan nilai 'Total' terendah adalah
# 378.9275

# %% [markdown]
# ### Visualisasi Data

# %%
legend.groupby(['Type 1'])['Total'].mean().plot(kind = 'bar', figsize = (10, 5))
# Out:
# <AxesSubplot:xlabel='Type 1'>

# %%
non_legend.groupby(['Type 1'])['Total'].mean().plot(kind = 'bar', figsize = (10, 5))
# Out:
# <AxesSubplot:xlabel='Type 1'>

# %% [markdown]
# # 6. Pengambilan Kesimpulan

# %% [markdown]
# 1. Pokemon Legendary terkuat adalah 'Mega Mewtwo' dan 'Mega Rayquaza' yang memiliki nilai 'Total' 780
#
# 2. Pokemon Legendary terlemah memiliki nilai 'Total' 580
#
# 3. Pokemon legendary dengan rata rata terkuat adalah pokemon tipe 'Normal' dengan nilai 695
#
# 4. Pokemon non-Legendary terkuat memiliki nilai 'Total' sebesar 700
#
# 5. Pokemon non-Legendary terlemah adalah 'Sunkern' memiliki nilai 'Total' sebesar 180
#
# 6. Pokemon non-legendary dengan rata rata terkuat adalah pokemon tipe 'Dragon' dengan nilai 'Total' 476.85
#
# 7. Pokemon non-legendary dengan rata rata terlemah adalah pokemon tipe 'Bug' dengan nilai 'Total' 378.927536

# %% [markdown]
# ## 6.1 TABEL PEMBANTU

# %%
legend.loc[legend['Total']==780].head()
# Out:
#                  #   Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Mega Mewtwo X  150  Psychic  Fighting    780  106     190      100      154
# Mega Mewtwo Y  150  Psychic   Psychic    780  106     150       70      194
# Mega Rayquaza  384   Dragon    Flying    780  105     180      100      180
#
#                Sp. Def  Speed  Legendary
# Name
# Mega Mewtwo X      100    130       True
# Mega Mewtwo Y      120    140       True
# Mega Rayquaza      100    115       True

# %%
non_legend.loc[non_legend['Total']==700].head()
# Out:
#                   #  Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Mega Tyranitar  248    Rock     Dark    700  100     164      150       95
# Mega Salamence  373  Dragon   Flying    700   95     145      130      120
# Mega Metagross  376   Steel  Psychic    700   80     145      150      105
# Mega Garchomp   445  Dragon   Ground    700  108     170      115      120
#
#                 Sp. Def  Speed  Legendary
# Name
# Mega Tyranitar      120     71      False
# Mega Salamence       90    120      False
# Mega Metagross      110    110      False
# Mega Garchomp        95     92      False
